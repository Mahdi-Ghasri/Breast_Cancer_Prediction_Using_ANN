# %% [markdown]
# <div dir="rtl">
#     <font size="4">
#         <h1><strong>تمرین پیش‌بینی ابتلا به سرطان سینه با استفاده از شبکه‌های عصبی مصنوعی (ANN)</strong></h1>
#         <h2><li>مقدمه</li></h2>
#         <font size="4"> در این تمرین، شما با استفاده از مجموعه داده‌ای شامل ویژگی‌های بافتی استخراج‌شده از تصاویر
#             دیجیتالی نمونه‌های بیوپسی سینه، یک مدل یادگیری عمیق مبتنی بر <strong>شبکه‌های عصبی مصنوعی (Artificial Neural
#                 Networks)</strong> برای پیش‌بینی احتمال ابتلا به سرطان سینه توسعه خواهید داد. این پروژه به شما کمک
#             می‌کند تا مهارت‌های خود را در زمینه <strong>تحلیل داده‌های پزشکی، طراحی مدل‌های پیشرفته و ارزیابی دقیق
#                 مدل‌ها</strong> تقویت نمایید. </font>
#         <h2><li>توضیح دیتاست</li></h2>
#         <font size="4"> این مجموعه داده شامل <strong>۵۶۹ نمونه</strong> و <strong>۳۲ ویژگی</strong> معتبر (پس از حذف
#             ستون بدون مقدار) می‌باشد که از مرکز پزشکی Wisconsin تهیه شده است. هر نمونه مربوط به نتایج یک آزمایش می‌باشد
#             و به‌صورت دستی با استفاده از تصاویر دیجیتالی نمونه‌های بافت سینه ثبت شده است. ویژگی‌های این داده شامل
#             اندازه‌گیری‌های آماری برای خصوصیات مختلف سلولی است، از جمله: <ul>
#                 <li><strong>شعاع (radius)</strong>، <strong>بافت (texture)</strong>، <strong>محیط (perimeter)</strong>،
#                     <strong>مساحت (area)</strong></li>
#                 <li><strong>همواری (smoothness)، فشردگی (compactness)، فرورفتگی (concavity)</strong> و... در سه نسخه:
#                     مقدار میانگین، انحراف معیار، و بدترین مقدار</li>
#             </ul> متغیر هدف این مجموعه داده <strong>Diagnosis (تشخیص)</strong> است که می‌تواند یکی از دو مقدار
#             <strong>Malignant (بدخیم)</strong> یا <strong>Benign (خوش‌خیم)</strong> باشد. هدف نهایی این تمرین،
#             <strong>پیش‌بینی صحیح نوع توده</strong> با استفاده از ویژگی‌های عددی آن است. </font>
#         <h2><li>وظیفه شما در این تمرین</li></h2>
#         <font size="4">
#             <li>✅ <strong>کاوش و تحلیل داده‌ها:</strong> بررسی توزیع ویژگی‌ها، تحلیل همبستگی بین ویژگی‌ها، بررسی توازن
#                 کلاس‌ها.</li>
#             <li>✅ <strong>پیش‌پردازش داده‌ها:</strong> حذف ستون‌های نامعتبر (مانند Unnamed: 32)، تبدیل برچسب‌های متنی به
#                 عددی، نرمال‌سازی ویژگی‌های عددی، بررسی داده‌های پرت.</li>
#             <li>✅ <strong>طراحی و آموزش مدل:</strong> پیاده‌سازی <strong>شبکه عصبی چندلایه (ANN)</strong> با استفاده از
#                 لایه‌های Dense، توابع فعال‌سازی، dropout و regularization برای جلوگیری از overfitting.</li>
#             <li>✅ <strong>ارزیابی مدل:</strong> استفاده از معیارهایی مانند <strong>Accuracy، Precision، Recall،
#                     F1-score، AUC-ROC</strong> برای ارزیابی عملکرد مدل.</li>
#         </font>
#         <font size="4"> <strong>هدف نهایی:</strong> توسعه مدلی با دقت و قابلیت تعمیم بالا جهت <strong>تشخیص زودهنگام
#                 سرطان سینه</strong> و کمک به پزشکان در <strong>تصمیم‌گیری بالینی مؤثرتر و سریع‌تر.</strong> </font>
#     </font>
# </div>

# %% [markdown]
# <div dir="rtl">
#     <font size="4">
#         <h2><strong>متغیر هدف (Target Variable)</strong></h2>
#         <font size="4">
#         متغیر هدف در این تمرین <strong>diagnosis</strong> است که مشخص می‌کند آیا توده‌ی مشاهده‌شده در بافت سینه خوش‌خیم (Benign) یا بدخیم (Malignant) است:
#             <li><strong>diagnosis = M:</strong> نشان‌دهنده‌ی توده‌ی سرطانی و بدخیم (Malignant)</li>
#             <li><strong>diagnosis = B:</strong> نشان‌دهنده‌ی توده‌ی خوش‌خیم (Benign)</li>
#         </font>
#         <font size=4>
#         <h2><strong>نحوه ارسال تمرین</strong></h2>
#         <font size="4">
#             <li>📌 فایل نوت‌بوک یا اسکریپت پروژه خود را در یک <strong>مخزن (Repository) در حساب GitHub</strong> خود آپلود نمایید.</li>
#             <li>📌 لینک مخزن را کپی کرده و در <strong>پنل لنمیس</strong> ارسال کنید.</li>
#             🔴 <strong>توجه داشته باشید که مخزن شما باید به‌صورت عمومی (Public) تنظیم شده باشد تا امکان بررسی تمرین فراهم گردد.</strong>
#         </font>
#     </font>
# </div>
# <br>

# %% [markdown]
# <div dir="rtl">
#     <h2><li>راهنمای تمرین:</li><h2>
#     <p>
#         <font size=4>
#         این تمرین به گونه‌ای طراحی شده که شما باید کدهای خود را در قالب خاصی که از قبل مشخص شده، بنویسید. به این معنی که ممکن است بخشی از کد برای شما آماده باشد و شما باید فقط ادامه کد را بنویسید بدون اینکه آن قسمت از کد را تغییر دهید. این نوع تمرین برای کمک به شما طراحی شده تا در مراحل بعدی با چالش‌های پیچیده‌تری روبرو شوید که نیاز به مهارت‌های بیشتری دارند.
#         <br>
#         در این تمرین، در هر مرحله شما باید برداشت‌ها و تحلیل‌های خود را بنویسید. مثلاً اگر در کد شما نمودار یا جدولی از داده‌ها یا نتایج مدل‌ها به نمایش در می‌آید، شما باید توضیح دهید که آن‌ها چه معنی و کاربردی دارند. این تحلیل‌ها می‌تواند شامل بررسی تغییرات در داده‌ها، ارزیابی مدل‌ها، یا نتایج بهینه‌سازی‌ها باشد.
#         <br>
#         برای هر بخش، حداقل پنج نکته یا برداشت از نتایج یا داده‌ها باید بنویسید.
#         <br>
#             <li>
#             در قسمت ارزیابی , باید یافته ها و نکاتی که از تحلیل داده متوجه شده و دریافت کرده اید در قالب یک خلاصه گزارش , بنویسید.
#             </li>
#             <li>
#             برای هر نمودار یا جدول، تحلیل کنید که چه روندی را نشان می‌دهند یا آیا نکته خاصی برای بهبود مدل یا داده‌ها از آن‌ها قابل استخراج است.
#             </li>
#             <br>
#         مهم است که توجه داشته باشید شما باید فقط کدهای خود را اضافه کنید و قسمت‌هایی که از پیش نوشته شده‌اند، نباید تغییر کنند. هدف این است که شما بتوانید با استفاده از قالب و راهنمایی‌های داده شده، تمرین را به درستی تکمیل کنید. <font color='green'>در صورتی که اصلا نتوانستید متد های خواسته شده را پیاده سازی کنید , سعی کنید به روش خودتان به خروجی مورد نظر برسید.</font>
#         </font>
#     </p>
# </div>
# <br>
# <br>
# <br>

# %% [markdown]
# <div dir="rtL">
#     <h2><li> متادیتای دیتاست </li></h2>
# </div>
#
# | **Section**                      | **Feature**                  | **Details**                                                                                                                                                       |
# |----------------------------------|-------------------------------|-------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | **Identification**               | `id`                          | Unique identifier for each patient/sample.                                                                                                                        |
# |                                  | `Unnamed: 32`                 | Empty column with all missing values; can be dropped.                                                                                                             |
# | **Diagnosis**                    | `diagnosis`                   | Diagnosis result: `'M'` indicates **Malignant** (cancerous), `'B'` indicates **Benign** (non-cancerous).                                                         |
# | **Mean Features**                | `radius_mean`                 | Mean radius of cell nuclei.                                                                                                                                       |
# |                                  | `texture_mean`               | Mean texture (standard deviation of gray-scale values).                                                                                                           |
# |                                  | `perimeter_mean`             | Mean perimeter of the cell nuclei.                                                                                                                                |
# |                                  | `area_mean`                  | Mean area of the cell nuclei.                                                                                                                                     |
# |                                  | `smoothness_mean`            | Mean smoothness (local variation in radius lengths).                                                                                                              |
# |                                  | `compactness_mean`           | Mean compactness (perimeter² / area - 1.0).                                                                                                                       |
# |                                  | `concavity_mean`             | Mean concavity (severity of concave portions of the contour).                                                                                                     |
# |                                  | `concave points_mean`        | Mean number of concave points on the contour.                                                                                                                     |
# |                                  | `symmetry_mean`              | Mean symmetry of the cell nuclei.                                                                                                                                 |
# |                                  | `fractal_dimension_mean`     | Mean fractal dimension (coastline approximation – complexity of the border).                                                                                      |
# | **Standard Error Features**      | `radius_se`                  | Standard error of radius.                                                                                                                                        |
# |                                  | `texture_se`                 | Standard error of texture.                                                                                                                                       |
# |                                  | `perimeter_se`               | Standard error of perimeter.                                                                                                                                     |
# |                                  | `area_se`                    | Standard error of area.                                                                                                                                          |
# |                                  | `smoothness_se`              | Standard error of smoothness.                                                                                                                                    |
# |                                  | `compactness_se`             | Standard error of compactness.                                                                                                                                   |
# |                                  | `concavity_se`               | Standard error of concavity.                                                                                                                                    |
# |                                  | `concave points_se`          | Standard error of concave points.                                                                                                                                |
# |                                  | `symmetry_se`                | Standard error of symmetry.                                                                                                                                      |
# |                                  | `fractal_dimension_se`       | Standard error of fractal dimension.                                                                                                                             |
# | **Worst (Largest) Features**     | `radius_worst`               | Worst (maximum) value of radius.                                                                                                                                 |
# |                                  | `texture_worst`              | Worst value of texture.                                                                                                                                          |
# |                                  | `perimeter_worst`            | Worst value of perimeter.                                                                                                                                        |
# |                                  | `area_worst`                 | Worst value of area.                                                                                                                                             |
# |                                  | `smoothness_worst`           | Worst value of smoothness.                                                                                                                                       |
# |                                  | `compactness_worst`          | Worst value of compactness.                                                                                                                                      |
# |                                  | `concavity_worst`            | Worst value of concavity.                                                                                                                                        |
# |                                  | `concave points_worst`       | Worst value of concave points.                                                                                                                                   |
# |                                  | `symmetry_worst`             | Worst value of symmetry.                                                                                                                                         |
# |                                  | `fractal_dimension_worst`    | Worst value of fractal dimension.                                                                                                                                |

# %% [markdown]
# <br><br>
# <div dir="rtl">
#   <h2>🔴دسته‌بندی ویژگی‌ها در دیتاست</h2>
#   <font size="4">
#       ویژگی‌های این دیتاست مربوط به بررسی بافت و ساختار هسته‌ی سلول‌های سینه در تصاویر میکروسکوپی هستند. این ویژگی‌ها از نظر آماری و هندسی در سه گروه زیر طبقه‌بندی شده‌اند که هر گروه می‌تواند در تشخیص خوش‌خیم یا بدخیم بودن توده‌ها نقش کلیدی داشته باشد.<br>
#       <li>
#         <b>ویژگی‌های میانگین (Mean Features):</b>
#         <br>
#         این گروه از ویژگی‌ها میانگین اندازه‌گیری‌های مربوط به هر نمونه را توصیف می‌کنند. مثلاً <code>radius_mean</code> میانگین شعاع هسته‌هاست و <code>texture_mean</code> میانگین بافت تصویر است. این مقادیر نمای کلی از ساختار فیزیکی توده را ارائه می‌دهند.
#         در بحث‌های هندسی، این ویژگی‌ها معمولاً با مشخصه‌های اصلی شکل هندسی (مساحت، محیط، شعاع، یکنواختی، پیچیدگی مرز و ...) مرتبط هستند.
#       </li>
#       <br>
#       <li>
#         <b>ویژگی‌های خطای استاندارد (Standard Error Features):</b>
#         <br>
#         این دسته نشان‌دهنده‌ی میزان نوسان یا پراکندگی اندازه‌گیری‌ها برای هر ویژگی هستند. مثلاً <code>radius_se</code> مقدار انحراف استاندارد اندازه شعاع‌ها در نقاط مختلف سلول است.
#         این ویژگی‌ها به شما اطلاعاتی در مورد <u>پایداری</u> ساختار یا تغییرپذیری شکل سلول می‌دهند. در پردازش هندسی، نوسان بالا ممکن است نشانگر لبه‌های نامنظم یا تغییرات غیرنرمال در بافت باشد.
#       </li>
#       <br>
#       <li>
#         <b>ویژگی‌های بزرگ‌ترین مقدار (Worst / Largest Features):</b>
#         <br>
#         این گروه نماینده‌ی بیشترین مقدار مشاهده‌شده برای هر ویژگی است (مثلاً <code>radius_worst</code> بزرگ‌ترین شعاع مشاهده‌شده در مرز سلول).
#         این مقادیر معمولاً نشان‌دهنده‌ی حداکثر انحراف از حالت عادی هستند و در طبقه‌بندی توده‌های بدخیم که تمایل به رشد نامنظم دارند، بسیار مهم‌اند.
#         در هندسه‌ی محاسباتی، این ویژگی‌ها می‌توانند نمایانگر نقاطی با بیش‌ترین تحدب، پیچیدگی یا بی‌نظمی باشند.
#       </li>
#       <br><br>
#       <font size=4 color='red'>جمع‌بندی</font>: در فرآیند Feature Engineering، درک دقیق این سه دسته ویژگی به شما کمک می‌کند تا بتوانید با ترکیب آن‌ها، ویژگی‌های جدید هندسی بسازید (مانند نسبت حداکثر به میانگین، ضریب نوسان، نسبت سطح به محیط، و غیره) که به مدل در تشخیص دقیق‌تر کمک خواهند کرد.
#   </font>
# </div>
# <br><br><br>

# %% [markdown]
# <br>
# <br>
# <div dir="rtl">
#         <h1><li>ارزیابی و شناخت دیتاست</li></h1>
# <font size=4>
#     در این قدم، شما باید دیتاست را بررسی کرده و ساختار آن را درک کنید. بررسی کنید که چه متغیرهایی در دیتاست وجود دارند، نوع داده‌ها چیست و آیا داده‌ها گمشده یا نادرست هستند یا خیر. این مرحله به شما کمک می‌کند که به‌طور کامل با داده‌ها آشنا شوید و مشکلات احتمالی را شناسایی کنید.
# </font>

# %%
# TODO: کتابخانه ها را ایمپورت کنید
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
# TODO: دیتافریم را لود کنید
df = pd.read_csv("/content/data.csv")

# %% [markdown]
# <div dir="rtl">
#     <h2><li>راهنمای تکمیل تابع <code>explore_dataset</code></li></h2>
#         <font size=4>
#         در این تمرین، هدف بررسی مقدماتی کیفیت و ساختار دیتاست با استفاده از یک تابع پایتونی به نام <code>explore_dataset</code> است. این تابع باید اطلاعات پایه‌ای راجع به دیتافریم ورودی را نمایش دهد تا آماده‌سازی داده‌ها برای مراحل بعدی تحلیل یا مدل‌سازی راحت‌تر شود.
#     <h3><strong>هدف اصلی تابع:</strong></h3>
#         <li>نمایش خلاصه‌ای از اطلاعات دیتافریم (تعداد ستون‌ها، نوع داده‌ها، مقادیر غیر‌خالی)</li>
#         <li>شناسایی ستون‌هایی که دارای داده‌های گم‌شده هستند</li>
#         <li>محاسبه تعداد ردیف‌های تکراری در دیتافریم</li>
#         <li>بررسی تعداد مقادیر یکتا در هر ستون</li>
#         <li>نمایش نوع داده‌ (Data Type) هر ستون</li>
#     <h3><strong>آنچه از شما انتظار می‌رود:</strong></h3>
#         <li>هر بخش از تابع را با دقت تکمیل کنید تا خروجی‌های واضح و مفیدی تولید کند.</li>
#         <li>در صورت تمایل، می‌توانید قسمت‌هایی برای رسم نمودارهای تکمیلی اضافه کنید (اختیاری).</li>
#         <li>در پایان اجرا، خروجی باید نمایی خلاصه و قابل فهم از وضعیت فعلی دیتاست ارائه دهد.</li>
#     <h3><strong>نکته پایانی:</strong></h3>
#         <font size=4>
#         این نوع توابع برای هر پروژه‌ی داده‌کاوی یا یادگیری ماشین به‌عنوان یک گام ابتدایی ضروری هستند. با تسلط بر این بررسی‌ها، شما درک عمیق‌تری از داده‌های خام پیدا خواهید کرد و تصمیمات بهتری در مراحل بعدی می‌گیرید.
# </div>

# %%
# TODO : تابع زیر را کامل کنید
def explore_dataset(df):
    """
    انجام بررسی اولیه روی یک دیتافریم pandas.

    پارامترها
    ----------
    df : pd.DataFrame
        دیتافریم ورودی که باید بررسی شود.

    name : str, اختیاری (پیش‌فرض: "Dataset")
        نام دیتاست برای نمایش در خروجی‌ها.

    عملکرد تابع
    ------------
    - نمایش اطلاعات کلی دیتافریم با استفاده از df.info().
    - نمایش تعداد داده‌های گم‌شده در هر ستون.
    - گزارش تعداد ردیف‌های تکراری.
    - نمایش تعداد مقادیر یکتا برای هر ستون.
    - نمایش نوع داده‌ای (dtype) تمام ستون‌ها.
    """
    print("="*60)
    print(f"بررسی اولیه دیتاست:")
    print("="*60)

    # اطلاعات کلی دیتاست
    print("\n[1] اطلاعات کلی (info):")
    print("-" * 50)
    print(df.info())

    # داده‌های گم شده
    print("\n[2] تعداد داده‌های گم‌شده در هر ستون:")
    print("-" * 50)
    missing = df.isnull().sum()
    missing = missing[missing > 0]
    if missing.empty:
        print("هیچ داده گم‌شده‌ای یافت نشد.")
    else:
        print(missing)

    # داده‌های تکراری
    print("\n[3] تعداد ردیف‌های تکراری:")
    print("-" * 50)
    duplicates = df.duplicated().sum()
    print(f"{duplicates} ردیف تکراری یافت شد.")

    # تعداد مقادیر یکتا در هر ستون
    print("\n[4] تعداد مقادیر یکتا در هر ستون:")
    print("-" * 50)
    unique_counts = df.nunique().sort_values(ascending=True)
    print(unique_counts)

    # نوع داده‌ها
    print("\n[5] نوع داده‌ها:")
    print("-" * 50)
    dtypes = df.dtypes
    print(dtypes)

    print("\nبررسی اولیه با موفقیت انجام شد.")
    print("="*60)

# %%
explore_dataset(df)
# Out:
# ============================================================
# بررسی اولیه دیتاست:
# ============================================================
#
# [1] اطلاعات کلی (info):
# --------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
#  14  perimeter_se             569 non-null    float64
#  15  area_se                  569 non-null    float64
#  16  smoothness_se            569 non-null    float64
#  17  compactness_se           569 non-null    float64
#  18  concavity_se             569 non-null    float64
#  19  concave points_se        569 non-null    float64
#  20  symmetry_se              569 non-null    float64
#  21  fractal_dimension_se     569 non-null    float64
#  22  radius_worst             569 non-null    float64
#  23  texture_worst            569 non-null    float64
#  24  perimeter_worst          569 non-null    float64
#  25  area_worst               569 non-null    float64
#  26  smoothness_worst         569 non-null    float64
#  27  compactness_worst        569 non-null    float64
#  28  concavity_worst          569 non-null    float64
#  29  concave points_worst     569 non-null    float64
#  30  symmetry_worst           569 non-null    float64
#  31  fractal_dimension_worst  569 non-null    float64
#  32  Unnamed: 32              0 non-null      float64
# dtypes: float64(31), int64(1), object(1)
# memory usage: 146.8+ KB
# None
#
# [2] تعداد داده‌های گم‌شده در هر ستون:
# --------------------------------------------------
# Unnamed: 32    569
# dtype: int64
#
# [3] تعداد ردیف‌های تکراری:
# --------------------------------------------------
# 0 ردیف تکراری یافت شد.
#
# [4] تعداد مقادیر یکتا در هر ستون:
# --------------------------------------------------
# Unnamed: 32                  0
# diagnosis                    2
# smoothness_worst           411
# symmetry_mean              432
# radius_mean                456
# radius_worst               457
# smoothness_mean            474
# texture_mean               479
# concave points_worst       492
# symmetry_se                498
# fractal_dimension_mean     499
# symmetry_worst             500
# concave points_se          507
# texture_worst              511
# perimeter_worst            514
# texture_se                 519
# perimeter_mean             522
# area_se                    528
# compactness_worst          529
# perimeter_se               533
# concavity_se               533
# fractal_dimension_worst    535
# concavity_mean             537
# compactness_mean           537
# concavity_worst            539
# area_mean                  539
# radius_se                  540
# compactness_se             541
# concave points_mean        542
# area_worst                 544
# fractal_dimension_se       545
# smoothness_se              547
# id                         569
# dtype: int64
#
# [5] نوع داده‌ها:
# --------------------------------------------------
# id                           int64
# diagnosis                   object
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# compactness_worst          float64
# concavity_worst            float64
# concave points_worst       float64
# symmetry_worst             float64
# fractal_dimension_worst    float64
# Unnamed: 32                float64
# dtype: object
#
# بررسی اولیه با موفقیت انجام شد.
# ============================================================

# %% [markdown]
# <div dir="rtl">
#     <p>
#         <font size=4>
#             <li>
#                 جدول Describe را برای این دیتافریم بررسی کنید
#             </li>
#         </font>
#     </p>
# </div>

# %%
# TODO: بررسی اطلاعات آمار و احتمالاتی دیتاست
df.describe().T
# Out:
#                          count          mean           std          min  \
# id                       569.0  3.037183e+07  1.250206e+08  8670.000000
# radius_mean              569.0  1.412729e+01  3.524049e+00     6.981000
# texture_mean             569.0  1.928965e+01  4.301036e+00     9.710000
# perimeter_mean           569.0  9.196903e+01  2.429898e+01    43.790000
# area_mean                569.0  6.548891e+02  3.519141e+02   143.500000
# smoothness_mean          569.0  9.636028e-02  1.406413e-02     0.052630
# compactness_mean         569.0  1.043410e-01  5.281276e-02     0.019380
# concavity_mean           569.0  8.879932e-02  7.971981e-02     0.000000
# concave points_mean      569.0  4.891915e-02  3.880284e-02     0.000000
# symmetry_mean            569.0  1.811619e-01  2.741428e-02     0.106000
# fractal_dimension_mean   569.0  6.279761e-02  7.060363e-03     0.049960
# radius_se                569.0  4.051721e-01  2.773127e-01     0.111500
# texture_se               569.0  1.216853e+00  5.516484e-01     0.360200
# perimeter_se             569.0  2.866059e+00  2.021855e+00     0.757000
# area_se                  569.0  4.033708e+01  4.549101e+01     6.802000
# smoothness_se            569.0  7.040979e-03  3.002518e-03     0.001713
# compactness_se           569.0  2.547814e-02  1.790818e-02     0.002252
# concavity_se             569.0  3.189372e-02  3.018606e-02     0.000000
# concave points_se        569.0  1.179614e-02  6.170285e-03     0.000000
# symmetry_se              569.0  2.054230e-02  8.266372e-03     0.007882
# fractal_dimension_se     569.0  3.794904e-03  2.646071e-03     0.000895
# radius_worst             569.0  1.626919e+01  4.833242e+00     7.930000
# texture_worst            569.0  2.567722e+01  6.146258e+00    12.020000
# perimeter_worst          569.0  1.072612e+02  3.360254e+01    50.410000
# area_worst               569.0  8.805831e+02  5.693570e+02   185.200000
# smoothness_worst         569.0  1.323686e-01  2.283243e-02     0.071170
# compactness_worst        569.0  2.542650e-01  1.573365e-01     0.027290
# concavity_worst          569.0  2.721885e-01  2.086243e-01     0.000000
# concave points_worst     569.0  1.146062e-01  6.573234e-02     0.000000
# symmetry_worst           569.0  2.900756e-01  6.186747e-02     0.156500
# fractal_dimension_worst  569.0  8.394582e-02  1.806127e-02     0.055040
# Unnamed: 32                0.0           NaN           NaN          NaN
#
#                                    25%            50%           75%  \
# id                       869218.000000  906024.000000  8.813129e+06
# radius_mean                  11.700000      13.370000  1.578000e+01
# texture_mean                 16.170000      18.840000  2.180000e+01
# perimeter_mean               75.170000      86.240000  1.041000e+02
# area_mean                   420.300000     551.100000  7.827000e+02
# smoothness_mean               0.086370       0.095870  1.053000e-01
# compactness_mean              0.064920       0.092630  1.304000e-01
# concavity_mean                0.029560       0.061540  1.307000e-01
# concave points_mean           0.020310       0.033500  7.400000e-02
# symmetry_mean                 0.161900       0.179200  1.957000e-01
# fractal_dimension_mean        0.057700       0.061540  6.612000e-02
# radius_se                     0.232400       0.324200  4.789000e-01
# texture_se                    0.833900       1.108000  1.474000e+00
# perimeter_se                  1.606000       2.287000  3.357000e+00
# area_se                      17.850000      24.530000  4.519000e+01
# smoothness_se                 0.005169       0.006380  8.146000e-03
# compactness_se                0.013080       0.020450  3.245000e-02
# concavity_se                  0.015090       0.025890  4.205000e-02
# concave points_se             0.007638       0.010930  1.471000e-02
# symmetry_se                   0.015160       0.018730  2.348000e-02
# fractal_dimension_se          0.002248       0.003187  4.558000e-03
# radius_worst                 13.010000      14.970000  1.879000e+01
# texture_worst                21.080000      25.410000  2.972000e+01
# perimeter_worst              84.110000      97.660000  1.254000e+02
# area_worst                  515.300000     686.500000  1.084000e+03
# smoothness_worst              0.116600       0.131300  1.460000e-01
# compactness_worst             0.147200       0.211900  3.391000e-01
# concavity_worst               0.114500       0.226700  3.829000e-01
# concave points_worst          0.064930       0.099930  1.614000e-01
# symmetry_worst                0.250400       0.282200  3.179000e-01
# fractal_dimension_worst       0.071460       0.080040  9.208000e-02
# Unnamed: 32                        NaN            NaN           NaN
#
#                                   max
# id                       9.113205e+08
# radius_mean              2.811000e+01
# texture_mean             3.928000e+01
# perimeter_mean           1.885000e+02
# area_mean                2.501000e+03
# smoothness_mean          1.634000e-01
# compactness_mean         3.454000e-01
# concavity_mean           4.268000e-01
# concave points_mean      2.012000e-01
# symmetry_mean            3.040000e-01
# fractal_dimension_mean   9.744000e-02
# radius_se                2.873000e+00
# texture_se               4.885000e+00
# perimeter_se             2.198000e+01
# area_se                  5.422000e+02
# smoothness_se            3.113000e-02
# compactness_se           1.354000e-01
# concavity_se             3.960000e-01
# concave points_se        5.279000e-02
# symmetry_se              7.895000e-02
# fractal_dimension_se     2.984000e-02
# radius_worst             3.604000e+01
# texture_worst            4.954000e+01
# perimeter_worst          2.512000e+02
# area_worst               4.254000e+03
# smoothness_worst         2.226000e-01
# compactness_worst        1.058000e+00
# concavity_worst          1.252000e+00
# concave points_worst     2.910000e-01
# symmetry_worst           6.638000e-01
# fractal_dimension_worst  2.075000e-01
# Unnamed: 32                       NaN

# %% [markdown]
# <div dir='rtl'>
# <font size=4>
# <h2>توضیح جدول آماری <code>describe()</code></h2>
# >جدول آماری حاصل از متد <code>describe()</code> اطلاعات آماری خلاصه‌ای از هر ویژگی (ستون) در دیتاست ارائه می‌دهد. این اطلاعات شامل:
#   <li><strong>count:</strong> تعداد مقادیر غیر تهی (برای بررسی missing values)</li>
#   <li><strong>mean:</strong> میانگین مقادیر</li>
#   <li><strong>std:</strong> انحراف معیار (نمایانگر میزان پراکندگی)</li>
#   <li><strong>min / 25% / 50% / 75% / max:</strong> مقادیر پرتایل (کوچک‌ترین، چارک اول، میانه، چارک سوم و بیشترین مقدار)</li>
# <h4>نکات کلیدی:</h4>
# <font size=4>
#   <li>ویژگی‌هایی مانند <code>radius_mean</code>، <code>area_mean</code> و <code>perimeter_mean</code> پراکندگی بالایی دارند و تفاوت قابل توجهی بین نمونه‌ها نشان می‌دهند.</li>
#   <li>ویژگی‌هایی مانند <code>smoothness_mean</code> و <code>fractal_dimension_mean</code> دارای محدوده نرمال‌تری هستند و مقدارشان به صورت متمرکزتر توزیع شده است.</li>
#   <li>ستون <code>Unnamed: 32</code> فقط مقادیر تهی دارد و باید حذف شود.</li>
#   <li>ستون <code>id</code> تنها یک شناسه است و برای تحلیل آماری یا مدل‌سازی کاربرد ندارد.</li>
# </div>

# %%
# TODO: توزیع داده ها در متغییر هدف بررسی کنید تا مشخص شود ایا دیتاست بالانس است یا خیر
df['diagnosis'].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %% [markdown]
# <br><br>
# <div dir="rtl">
# <font size="4">
#     <li>
#         در ادامه باید یک سری از ویژگی های دیگر را حذف کنید.
#     </li>
# </font>
# </div>

# %%
# TODO: حذف ویژگی های ترکیب شده ( در صورتی که لازم است)
df = df.drop(columns=['id', 'Unnamed: 32'])

# %% [markdown]
# <br>
# <br>
# <div dir="rtl">
# <h1>
#     <li>
#     <strong>مصورسازی</strong>
#     </li>
# </h1>
# <font size=4>
#     در این قدم، شما باید با استفاده از ابزارهای مصورسازی مانند نمودارهای پراکندگی (Scatter plots)، هیستوگرام‌ها و نمودارهای جعبه‌ای (Box plots)، روابط بین ویژگی‌ها و هدف را بررسی کنید. این مرحله به شما کمک می‌کند که روابط پنهان میان متغیرها را شناسایی کنید و درک بهتری از داده‌ها پیدا کنید. شما میتوانید هرگونه مصورسازی که فکر می کنید در این مرحله اطلاعاتی به شما میدهد را انجام دهید.
#     ولی پیاده سازی پلات های خواسته شده الزامی می باشد.
# </font>
# <br>
# <br><br>

# %% [markdown]
# <br>
# <br>
# <div dir="rtl">
#     <h2><li>Histogram:</li></H2>
#     <font size="4">
#             در سلول زیر باید ویژگی های عددی (ویژگی های عددی Continous) را جدا کنید و از آنها برای رسم نمودار هیستوگرام و بررسی توزیع داده ها استفاده کنید.
#     </font>
#         <br>
#     <font size="4">
#         نکته :همچنین از آنجایی که تعداد متغیر ها زیاد است , سعی کنید از Subplot برای خوانا تر شدن و زیبایی بیشتر کد استفاده کنید.
#     </font>
# </div>
# <br>
# <br>

# %%
# داده های عددی
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns

# %%
# TODO: متد زیر را برای نشان دادن هیستوگرام تکمیل و متغیر های ذکر شده را بررسی کنید.
def plot_numerical_histograms(df, numerical_cols, bins=100):
    """
    رسم هیستوگرام برای ستون‌های عددی با استفاده از subplot.

    پارامترها:
    - df: دیتافریم ورودی
    - numerical_cols: لیست ویژگی‌های عددی
    - bins: تعداد سطل‌های هیستوگرام (پیش‌فرض: 30)
    """
    plt.figure(figsize=(8, 15))
    for i, col in enumerate(numerical_cols):
        plt.subplot(9, 2, i + 1)
        sns.histplot(df[col], kde=True,
                     bins=bins, color='skyblue')
        plt.title(f'Histogram of {col}',
                  fontsize=10,
                  fontweight='bold')
        plt.xlabel(col, fontsize=10)
        plt.ylabel('Frequency', fontsize=10)
        plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
# TODO: از تابع نوشته استفاده کنید و هیستوگرام ویژگی های عددی را رسم کنید.
plot_numerical_histograms(df, numerical_cols[0:17])

# %%
plot_numerical_histograms(df, numerical_cols[18:])

# %% [markdown]
# <div dir="rtl">
#   <h2>تحلیل توزیع ویژگی‌ها بر اساس هیستوگرام</h2>
#   <font size="4">
#     بر اساس هیستوگرام‌های موجود در دو تصویر، می‌توان نکات کلیدی زیر را درباره توزیع ویژگی‌های دیتاست بیان کرد:
#   </font>
#
#   <h2>نکات مهم:</h2>
#
#   <h3>1. <strong>توزیع نرمال (Normal-like Distribution):</strong></h3>
#   <font size="4">
#     ویژگی‌هایی که توزیعی نسبتاً نرمال دارند:
#     <br>
#     - texture_mean<br>
#     - smoothness_mean<br>
#     - symmetry_mean<br>
#     - smoothness_worst<br>
#     - symmetry_worst<br>
#     این ویژگی‌ها احتمالاً برای مدل‌های آماری مناسب‌تر هستند و نیاز به نرمال‌سازی شدید ندارند.
#   </font>
#
#   <h3>2. <strong>توزیع چپ‌چوله یا راست‌چوله (Skewed Distribution):</strong></h3>
#   <font size="4">
#     بسیاری از ویژگی‌ها به‌شدت skewed هستند (چوله به راست)، مانند:
#     <br>
#     - area_mean<br>
#     - radius_se<br>
#     - area_se<br>
#     - compactness_worst<br>
#     - concavity_worst<br>
#     - area_worst<br>
#     این ویژگی‌ها ممکن است نیاز به <strong>log transform</strong> یا <strong>standardization</strong> داشته باشند.
#   </font>
#
#   <h3>3. <strong>ویژگی‌هایی با مقادیر بسیار کوچک:</strong></h3>
#   <font size="4">
#     برخی ویژگی‌ها مثل:
#     <br>
#     - smoothness_se<br>
#     - fractal_dimension_se<br>
#     - symmetry_se<br>
#     دارای مقدارهای خیلی کوچک و تمرکز بالا در نزدیکی صفر هستند. ممکن است در مدل‌سازی نیاز به <strong>scaling دقیق‌تر</strong> داشته باشند.
#   </font>
#
#   <h3>4. <strong>پراکندگی بالا:</strong></h3>
#   <font size="4">
#     ویژگی‌هایی مانند:
#     <br>
#     - area_mean<br>
#     - area_se<br>
#     - area_worst<br>
#     - radius_worst<br>
#     دارای دامنه‌ی مقدار بسیار وسیع هستند و باید <strong>نرمال‌سازی</strong> شوند تا مقیاس آنها با بقیه ویژگی‌ها برابر شود.
#   </font>
#
#   <h2>جمع‌بندی:</h2>
#   <font size="4">
#     - بخش زیادی از ویژگی‌ها skewed هستند و نیاز به transform دارند.<br>
#     - برخی ویژگی‌ها به خوبی نرمال هستند.<br>
#     - نرمال‌سازی یا Standard Scaling روی کل دیتاست توصیه می‌شود.<br>
#     - برای مدل‌هایی مثل Logistic Regression یا SVM، <strong>مقیاس‌بندی ویژگی‌ها ضروری است</strong>.
#   </font>
# </div>

# %% [markdown]
# <br>
# <br>
# <div dir="rtl">
#     <h2><li>Countplot:</li></H2>
#     <font size="4">
#             میزان توزیع داده ها در متغیر هدف را بررسی کنید.
#     </font>
#         <br>
# </div>
# <br>
# <br>

# %%
# TODO: کدی بنویسید که متغیر هدف را با barplot نشان دهد
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='diagnosis', palette='Set2')
plt.title('Distribution of Diagnosis')
plt.xlabel('Diagnosis')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# <div dir="rtl">
# <font size="6">
#     <li>
#     <strong>مهندسی ویژگی / انتخاب ویژگی</strong>
#     </li>
# </font>
#     <font size=4>
#     در این مرحله، ویژگی‌های مناسب برای مدل‌سازی انتخاب شده و ویژگی‌های غیرضروری حذف یا اصلاح می‌شوند. مهندسی ویژگی شامل ایجاد ویژگی‌های جدید، تبدیل داده‌های دسته‌ای به عددی و ... است. هدف این مرحله بهبود عملکرد مدل با انتخاب ویژگی‌های تأثیرگذار و کاهش پیچیدگی داده‌ها است.
#     </font>
# </div>
# <br><br>

# %% [markdown]
# <br>
# <br>
# <div dir="rtl">
#     <font size=4>
#         <li>
#             در ابتدا یک کپی از دیتافریم اصلی بگیرید و ادامه تمرین را روی دیتافریم کپی شده انجام دهید.
#         </li>
#     </font>
# </div>

# %%
# TODO: از دیتافریم کپی بگیرید
df_copy = df.copy()

# %% [markdown]
# <br>
# <br>
# <div dir="rtl">
#     <h2>نسبت‌های هندسی بین اندازه‌ها (Shape Ratios)<h2>
#     <font size=4>
#         <li>
#             برای ویژگی‌هایی مانند radius, area, perimeter که اندازه‌های هندسی داده‌ها هستند، نسبت‌های مختلف بین این اندازه‌ها می‌توانند اطلاعات مهمی درباره شکل داده‌ها بدهند. برای مثال، نسبت area_mean به perimeter_mean می‌تواند ویژگی‌های جدید و مفیدی بسازد.
#         </li>
#     </font>
# </div>

# %%
# TODO
df_copy['perimeter_to_radius'] = df_copy['perimeter_mean'] / (2 * 3.14 * df_copy['radius_mean'])
df_copy['area_to_perimeter'] = df_copy['area_mean'] / df_copy['perimeter_mean']
df_copy['radius_ratio'] = df_copy['radius_worst'] / df_copy['radius_mean']
df_copy['area_ratio'] = df_copy['area_worst'] / df_copy['area_mean']

# %% [markdown]
# <br>
# <br>
# <div dir="rtl">
#     <h2>تفاضل بین نسخه‌های worst و mean (Worst - Mean Differences)<h2>
#     <font size=4>
#         <li>
#             برای ویژگی‌هایی مانند radius, area, perimeter که اندازه‌های هندسی داده‌ها هستند، نسبت‌های مختلف بین این اندازه‌ها می‌توانند اطلاعات مهمی درباره شکل داده‌ها بدهند. برای مثال، نسبت area_mean به perimeter_mean می‌تواند ویژگی‌های جدید و مفیدی بسازد.
#         </li>
#     </font>
# </div>

# %%
# TODO
df_copy['smoothness_diff'] = df_copy['smoothness_worst'] - df_copy['smoothness_mean']
df_copy['symmetry_diff'] = df_copy['symmetry_worst'] - df_copy['symmetry_mean']
df_copy['compactness_diff'] = df_copy['compactness_worst'] - df_copy['compactness_mean']
df_copy['concavity_diff'] = df_copy['concavity_worst'] - df_copy['concavity_mean']
df_copy['concave_points_diff'] = df_copy['concave points_worst'] - df_copy['concave points_mean']

# %% [markdown]
# <br>
# <br>
# <div dir="rtl">
#     <h2>ویژگی‌های شدت تغییرات نسبی (Relative Standard Error Features)<h2>
#     <font size=4>
#         <li>
#            برای هر ویژگی، محاسبه نسبت انحراف معیار به میانگین (Standard Error / Mean) می‌تواند نشان دهد که تغییرات آن ویژگی در مقایسه با مقدار میانگین چقدر زیاد است. این ویژگی‌ها می‌توانند شامل radius_se / radius_mean یا area_se / area_mean باشن
#         </li>
#     </font>
# </div>

# %%
# TODO
df_copy['radius_rel_error'] = df_copy['radius_se'] / df_copy['radius_mean']
df_copy['area_rel_error'] = df_copy['area_se'] / df_copy['area_mean']
df_copy['perimeter_rel_error'] = df_copy['perimeter_se'] / df_copy['perimeter_mean']
df_copy['texture_rel_error'] = df_copy['texture_se'] / df_copy['texture_mean']

# %% [markdown]
# <br>
# <br>
# <div dir="rtl">
#     <h2>میانگین هندسی ترکیبی ویژگی‌های با هم‌بستگی بالا (Composite Features)<h2>
#     <font size=4>
#         <li>
#            اگر ویژگی‌هایی مانند compactness_mean و compactness_worst هم‌بستگی بالایی داشته باشند، می‌توانید آن‌ها را ترکیب کرده و یک ویژگی جدید بسازید، مثل میانگین هندسی یا میانگین ساده این ویژگی‌ها برای کاهش ابعاد و استفاده بهینه از اطلاعات.
#         </li>
#     </font>
# </div>

# %%
# TODO
df_copy['malignancy_geom_mean'] = (df_copy['compactness_mean'] * df_copy['concavity_mean'] * df_copy['concave points_mean']) ** (1/3)

# %% [markdown]
# <br>
# <br>
# <div dir="rtl">
#     <h2>ترکیب میانگین و worst برای یک ویژگی نرمال‌شده (Averaged Features)<h2>
#     <font size=4>
#         <li>
#             برای ویژگی‌هایی مانند smoothness, symmetry, یا concavity, ترکیب مقادیر mean و worst می‌تواند ویژگی‌های جدیدی بسازد که هم نمایانگر رفتار کلی ویژگی‌ها در مدل‌های مختلف باشند.
#         </li>
#     </font>
# </div>

# %%
# TODO
df_copy['avg_radius'] = (df_copy['radius_mean'] + df_copy['radius_worst']) / 2
df_copy['avg_texture'] = (df_copy['texture_mean'] + df_copy['texture_worst']) / 2
df_copy['avg_symmetry'] = (df_copy['symmetry_mean'] + df_copy['symmetry_worst']) / 2

# %% [markdown]
# <br>
# <br>
# <div dir="rtl">
#     <h2> نسبت Worst به SE برای سنجش نوسانات ویژگی (Worst-to-SE Ratios)<h2>
#     <font size=4>
#         <li>
#             برای سنجش نوسانات و تغییرات در ویژگی‌ها، می‌توان نسبت مقادیر worst به SE برای ویژگی‌هایی مانند radius, area, smoothness و غیره محاسبه کرد. این ویژگی‌ها می‌توانند برای شناسایی ویژگی‌هایی با تغییرات زیاد مفید باشند.
#     </font>
# </div>

# %%
# TODO
df_copy['area_worst_se_ratio'] = df_copy['area_worst'] / (df_copy['area_se'] + 1e-5)                # مقدار بسیار کوچکی به مقادیر اضافه می کنیم برای جلوگیری از خطا تقسیم بر صفر
df_copy['radius_worst_se_ratio'] = df_copy['radius_worst'] / (df_copy['radius_se'] + 1e-5)
df_copy['perimeter_worst_se_ratio'] = df_copy['perimeter_worst'] / (df_copy['perimeter_se'] + 1e-5)

# %%
features_to_drop = [
    # نسخه‌های اولیه که با نسبت، اختلاف یا ترکیب جایگزین شدن
    'radius_mean', 'radius_worst', 'radius_se',
    'area_mean', 'area_worst', 'area_se',
    'perimeter_mean', 'perimeter_worst', 'perimeter_se',
    'texture_mean', 'texture_worst', 'texture_se',
    'smoothness_mean', 'smoothness_worst',
    'compactness_mean', 'compactness_worst', 'compactness_se',
    'concavity_mean', 'concavity_worst', 'concavity_se',
    'concave points_mean', 'concave points_worst', 'concave points_se',
    'symmetry_mean', 'symmetry_worst', 'symmetry_se',
    'fractal_dimension_mean', 'fractal_dimension_worst', 'fractal_dimension_se',
]

df_copy = df_copy.drop(columns=features_to_drop)

# %% [markdown]
# <br><br>
# <div dir="rtl">
# <font size="6">
#     <h1><li>آموزش مدل ANN:</li></h1>
# </div>

# %% [markdown]
# <div dir="rtl">
#     <font size=4>در این تمرین، شما باید یک مدل شبکه عصبی برای حل یک مسئله طبقه‌بندی بسازید. مدل شما باید شامل لایه‌های Dense باشد و از Regularizer و Dropout برای جلوگیری از Overfitting بهره ببرد.</font>
#     <h3>مراحل:</h3>
#         <h3><li>انتخاب تابع فعال‌سازی مناسب:</h3>
#             <font size=4>
#                 برای لایه‌های پنهانی مدل از توابع فعال‌سازی غیرخطی مانند ReLU استفاده کنید تا مدل بتواند روابط پیچیده و غیرخطی بین ویژگی‌ها را یاد بگیرد.<
#                 برای لایه خروجی، بسته به نوع مسئله طبقه‌بندی، باید تابع فعال‌سازی مناسب را انتخاب کنید. برای طبقه‌بندی دوتایی از تابع sigmoid و برای طبقه‌بندی چندکلاسه از softmax استفاده کنید.
#             <br>
#         <h3><li>استفاده از Regularizer و Dropout برای جلوگیری از Overfitting:</h3>
#             <font size=4>
#                 برای جلوگیری از Overfitting، از Regularizer (مانند L1 یا L2) در لایه‌های Dense استفاده کنید. این کار باعث می‌شود که وزن‌ها در مدل به اندازه کافی کوچک و منظم باقی بمانند.
#                 همچنین می‌توانید از لایه‌های Dropout استفاده کنید تا برخی از نرون‌ها به طور تصادفی در هر مرحله از آموزش غیرفعال شوند و از یادگیری ویژگی‌های غیرضروری جلوگیری شود.
#         <br>
#         <h3><li>انتخاب Loss Function مناسب:</li>
#             <font size=4>
#                 تابع خطا مناسب برای لایه ی خروجی انتخاب کنید.
#         <br>
#         <h3><li>آموزش مدل:</li>
#             <font size=4>
#                 بعد از طراحی مدل، باید آن را با استفاده از داده‌های آموزشی آموزش دهید. از Optimizer مناسب  برای بهبود عملکرد مدل در حین آموزش استفاده کنید.
#     <br>
#     <font size=4 color='green'>
#         در آخر، دلایل انتخاب تابع فعال‌سازی، تعداد لایه‌ها و نورون‌ها و تابع خطا را توضیح دهید.
# </div>

# %%
# TODO: کتابخانه های مورد نیاز را ایمپورت کنید
import tensorflow as tf
from tensorflow.keras import regularizers
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import confusion_matrix, classification_report

# %%
# تبدیل diagnosis به عدد
df_copy['diagnosis'] = df_copy['diagnosis'].map({'M': 1, 'B': 0})

# %%
# TODO:  متغیر های وابسه و مستقل را به X, y تقسیم
X = df_copy.drop(['diagnosis'], axis=1).values
y = df_copy['diagnosis'].values

# %%
# TODO: داده ها به مجموعه آموزش و تست تقسیم کنید

X_train, X_test, y_train, y_test = train_test_split(X, y ,test_size=0.1, random_state=42)

print(f"X Train :{X_train.shape}")
print(f"X Test :{X_test.shape}")
print(f"y Train :{y_train.shape}")
print(f"y Test :{y_test.shape}")
# Out:
# X Train :(512, 21)
# X Test :(57, 21)
# y Train :(512,)
# y Test :(57,)

# %% [markdown]
# <br>
# <br>
# <div dir="rtl">
#     <font size=4>
#         <li>
#             داده ها را Scale کنید و توضیح دهید که باید از MinMaxScaler استفاده شود یا StandardScaler ؟
#     </font>
# </div>

# %%
# TODO: داده ها را مقیاس بندی کنید
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# <br><br>
# <div dir="rtl">
#   <font size="4">
#     <li>
#       شبکه عصبی را طراحی کنید. در طراحی معماری مدل، لازم است از توابع <b>Regularizer</b> (جهت جلوگیری از overfitting) و <b>Initializer</b> مناسب (برای مقداردهی اولیه وزن‌ها به‌صورت پایدار و کارآمد) استفاده شود تا هم عملکرد مدل بهبود یابد و هم فرآیند آموزش پایدارتر گردد.
#     </li>
#   </font>
# </div>

# %% [markdown]
# <br>
# <div dir='rtl'>
#     <font size=4> منابع زیر جهت مطالعه بیشتر در خصوص متد ذکر شده می باشد.
# </div>
#
#
# * [Layer weight regularizers](https://keras.io/api/layers/regularizers/)
# * [Regularizer | Tensorflow](https://www.tensorflow.org/api_docs/python/tf/keras/Regularizer)
# * [Use Regularization Methods for NNs](https://datascience.stackexchange.com/questions/84667/is-it-better-to-use-separately-regularization-methods-for-neural-networks-l2-l1_)
# <br>

# %% [markdown]
# <br>
# <div dir='rtl'>
#     <font size=4> منابع زیر جهت مطالعه بیشتر در Initializer می باشد.
# </div>
#
# * [Initializers](https://www.tensorflow.org/api_docs/python/tf/keras/initializers)
# * [HeNormal](https://www.tensorflow.org/api_docs/python/tf/keras/initializers/HeNormal)
# <br><br>

# %%
# TODO: طراحی شبکه عصبی
def build_model(input_shape,
                        output_units=1,
                        output_activation='sigmoid',
                        learning_rate=1e-3,
                        metrics=['accuracy']):
    """
    مدل ANN ساده با مقدار متوسطی از dropout و regularization (L2).
    """
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(16, activation='relu',
                              kernel_initializer='he_uniform',
                              kernel_regularizer=regularizers.l2(0.01),
                              input_shape=(input_shape,)),
        tf.keras.layers.Dropout(0.1),

        tf.keras.layers.Dense(8, activation='relu',
                              kernel_initializer='he_uniform',
                              kernel_regularizer=regularizers.l2(0.01)),

        tf.keras.layers.Dropout(0.1),

        tf.keras.layers.Dense(output_units,
                              activation=output_activation,
                              kernel_initializer='glorot_uniform')
    ])

    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
    loss_fn = tf.keras.losses.BinaryCrossentropy()

    model.compile(optimizer=optimizer, loss=loss_fn, metrics=metrics)

    return model

# %% [markdown]
# <br><br>
# <div dir="rtl">
# <font size="4">
#     <li>
#         جدول summary مدل را در سلول زیر نشان دهید و دلیل مقادیر هر لایه را توضیح دهید.
# </font>
# </div>

# %%
model = build_model(input_shape=X_train.shape[1])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 16)             │           352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 8)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 497 (1.94 KB)
#  Trainable params: 497 (1.94 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# <br><br>
# <div dir="rtl">
# <font size="4">
#     <li>
#         مدل را آموزش دهید
# </font>
# </div>

# %%
history = model.fit(X_train, y_train,
                validation_data = (X_test, y_test),
                epochs=100,
                batch_size = 32)
# Out:
# Epoch 1/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.5058 - loss: 1.1584 - val_accuracy: 0.7018 - val_loss: 1.1064
# Epoch 2/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6823 - loss: 1.0995 - val_accuracy: 0.7368 - val_loss: 1.0480
# Epoch 3/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6730 - loss: 1.0629 - val_accuracy: 0.7193 - val_loss: 1.0018
# Epoch 4/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6332 - loss: 1.0283 - val_accuracy: 0.7719 - val_loss: 0.9612
# Epoch 5/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6890 - loss: 0.9829 - val_accuracy: 0.7895 - val_loss: 0.9149
# Epoch 6/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7059 - loss: 0.9473 - val_accuracy: 0.8772 - val_loss: 0.8581
# Epoch 7/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7527 - loss: 0.8827 - val_accuracy: 0.8947 - val_loss: 0.8065
# Epoch 8/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7988 - loss: 0.8447 - val_accuracy: 0.9298 - val_loss: 0.7655
# Epoch 9/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8262 - loss: 0.8144 - val_accuracy: 0.9298 - val_loss: 0.7236
# Epoch 10/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8143 - loss: 0.7722 - val_accuracy: 0.9474 - val_loss: 0.6849
# Epoch 11/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8326 - loss: 0.7360 - val_accuracy: 0.9474 - val_loss: 0.6436
# Epoch 12/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8575 - loss: 0.6986 - val_accuracy: 0.9474 - val_loss: 0.6144
# Epoch 13/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8386 - loss: 0.7017 - val_accuracy: 0.9649 - val_loss: 0.5800
# Epoch 14/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8878 - loss: 0.6196 - val_accuracy: 0.9649 - val_loss: 0.5516
# Epoch 15/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8657 - loss: 0.6344 - val_accuracy: 0.9649 - val_loss: 0.5264
# Epoch 16/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8654 - loss: 0.6009 - val_accuracy: 0.9649 - val_loss: 0.4991
# Epoch 17/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9201 - loss: 0.5417 - val_accuracy: 0.9649 - val_loss: 0.4763
# Epoch 18/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8979 - loss: 0.5263 - val_accuracy: 0.9649 - val_loss: 0.4553
# Epoch 19/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8734 - loss: 0.5416 - val_accuracy: 0.9649 - val_loss: 0.4359
# Epoch 20/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9088 - loss: 0.4964 - val_accuracy: 0.9649 - val_loss: 0.4199
# Epoch 21/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8872 - loss: 0.5085 - val_accuracy: 0.9649 - val_loss: 0.4055
# Epoch 22/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9247 - loss: 0.4848 - val_accuracy: 0.9649 - val_loss: 0.3884
# Epoch 23/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9034 - loss: 0.4755 - val_accuracy: 0.9649 - val_loss: 0.3746
# Epoch 24/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9240 - loss: 0.4430 - val_accuracy: 0.9649 - val_loss: 0.3618
# Epoch 25/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9185 - loss: 0.4347 - val_accuracy: 0.9649 - val_loss: 0.3530
# Epoch 26/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9235 - loss: 0.4354 - val_accuracy: 0.9649 - val_loss: 0.3407
# Epoch 27/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9170 - loss: 0.4341 - val_accuracy: 0.9649 - val_loss: 0.3322
# Epoch 28/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9133 - loss: 0.4156 - val_accuracy: 0.9649 - val_loss: 0.3239
# Epoch 29/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9146 - loss: 0.4033 - val_accuracy: 0.9649 - val_loss: 0.3158
# Epoch 30/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9416 - loss: 0.3797 - val_accuracy: 0.9649 - val_loss: 0.3077
# Epoch 31/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9235 - loss: 0.3907 - val_accuracy: 0.9825 - val_loss: 0.3007
# Epoch 32/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9175 - loss: 0.3940 - val_accuracy: 0.9825 - val_loss: 0.2942
# Epoch 33/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9116 - loss: 0.3890 - val_accuracy: 0.9825 - val_loss: 0.2878
# Epoch 34/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9391 - loss: 0.3460 - val_accuracy: 0.9825 - val_loss: 0.2822
# Epoch 35/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9269 - loss: 0.3507 - val_accuracy: 0.9825 - val_loss: 0.2765
# Epoch 36/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9134 - loss: 0.3695 - val_accuracy: 0.9825 - val_loss: 0.2721
# Epoch 37/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9159 - loss: 0.3796 - val_accuracy: 0.9825 - val_loss: 0.2683
# Epoch 38/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9280 - loss: 0.3466 - val_accuracy: 0.9825 - val_loss: 0.2639
# Epoch 39/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9526 - loss: 0.3122 - val_accuracy: 0.9825 - val_loss: 0.2596
# Epoch 40/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9284 - loss: 0.3379 - val_accuracy: 0.9825 - val_loss: 0.2563
# Epoch 41/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9236 - loss: 0.3428 - val_accuracy: 0.9825 - val_loss: 0.2530
# Epoch 42/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9343 - loss: 0.3260 - val_accuracy: 0.9825 - val_loss: 0.2487
# Epoch 43/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9525 - loss: 0.3237 - val_accuracy: 0.9825 - val_loss: 0.2454
# Epoch 44/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9221 - loss: 0.3401 - val_accuracy: 0.9825 - val_loss: 0.2420
# Epoch 45/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9613 - loss: 0.2759 - val_accuracy: 0.9825 - val_loss: 0.2387
# Epoch 46/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9420 - loss: 0.3249 - val_accuracy: 0.9825 - val_loss: 0.2356
# Epoch 47/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9413 - loss: 0.3005 - val_accuracy: 0.9825 - val_loss: 0.2333
# Epoch 48/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9417 - loss: 0.3086 - val_accuracy: 0.9825 - val_loss: 0.2325
# Epoch 49/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9658 - loss: 0.2899 - val_accuracy: 0.9825 - val_loss: 0.2294
# Epoch 50/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9521 - loss: 0.3017 - val_accuracy: 0.9825 - val_loss: 0.2272
# Epoch 51/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9296 - loss: 0.3169 - val_accuracy: 0.9825 - val_loss: 0.2252
# Epoch 52/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9446 - loss: 0.3134 - val_accuracy: 0.9825 - val_loss: 0.2228
# Epoch 53/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9532 - loss: 0.2792 - val_accuracy: 0.9825 - val_loss: 0.2209
# Epoch 54/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9409 - loss: 0.2872 - val_accuracy: 0.9825 - val_loss: 0.2197
# Epoch 55/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9350 - loss: 0.3067 - val_accuracy: 0.9825 - val_loss: 0.2180
# Epoch 56/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9319 - loss: 0.2977 - val_accuracy: 0.9825 - val_loss: 0.2166
# Epoch 57/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9421 - loss: 0.2866 - val_accuracy: 0.9825 - val_loss: 0.2138
# Epoch 58/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9594 - loss: 0.2663 - val_accuracy: 0.9825 - val_loss: 0.2119
# Epoch 59/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9400 - loss: 0.2820 - val_accuracy: 0.9825 - val_loss: 0.2109
# Epoch 60/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9466 - loss: 0.2774 - val_accuracy: 0.9825 - val_loss: 0.2099
# Epoch 61/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9605 - loss: 0.2578 - val_accuracy: 0.9825 - val_loss: 0.2079
# Epoch 62/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9622 - loss: 0.2809 - val_accuracy: 0.9825 - val_loss: 0.2059
# Epoch 63/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9634 - loss: 0.2509 - val_accuracy: 0.9825 - val_loss: 0.2048
# Epoch 64/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9469 - loss: 0.2605 - val_accuracy: 0.9825 - val_loss: 0.2030
# Epoch 65/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9505 - loss: 0.2703 - val_accuracy: 0.9825 - val_loss: 0.2019
# Epoch 66/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9595 - loss: 0.2403 - val_accuracy: 0.9825 - val_loss: 0.2003
# Epoch 67/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9502 - loss: 0.2662 - val_accuracy: 0.9825 - val_loss: 0.2003
# Epoch 68/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9493 - loss: 0.2705 - val_accuracy: 0.9825 - val_loss: 0.1995
# Epoch 69/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9377 - loss: 0.2607 - val_accuracy: 0.9825 - val_loss: 0.1982
# Epoch 70/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9585 - loss: 0.2600 - val_accuracy: 0.9825 - val_loss: 0.1956
# Epoch 71/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9697 - loss: 0.2430 - val_accuracy: 0.9825 - val_loss: 0.1940
# Epoch 72/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9527 - loss: 0.2571 - val_accuracy: 0.9825 - val_loss: 0.1937
# Epoch 73/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9621 - loss: 0.2434 - val_accuracy: 0.9825 - val_loss: 0.1935
# Epoch 74/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9559 - loss: 0.2635 - val_accuracy: 0.9825 - val_loss: 0.1928
# Epoch 75/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9726 - loss: 0.2207 - val_accuracy: 0.9825 - val_loss: 0.1920
# Epoch 76/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9595 - loss: 0.2399 - val_accuracy: 0.9825 - val_loss: 0.1922
# Epoch 77/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9620 - loss: 0.2396 - val_accuracy: 0.9825 - val_loss: 0.1906
# Epoch 78/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9440 - loss: 0.2522 - val_accuracy: 0.9825 - val_loss: 0.1899
# Epoch 79/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9542 - loss: 0.2441 - val_accuracy: 0.9825 - val_loss: 0.1891
# Epoch 80/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9643 - loss: 0.2305 - val_accuracy: 0.9825 - val_loss: 0.1885
# Epoch 81/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9695 - loss: 0.2254 - val_accuracy: 0.9825 - val_loss: 0.1878
# Epoch 82/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9796 - loss: 0.2232 - val_accuracy: 0.9825 - val_loss: 0.1866
# Epoch 83/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9626 - loss: 0.2492 - val_accuracy: 0.9825 - val_loss: 0.1853
# Epoch 84/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9590 - loss: 0.2315 - val_accuracy: 0.9825 - val_loss: 0.1845
# Epoch 85/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9658 - loss: 0.2460 - val_accuracy: 0.9825 - val_loss: 0.1842
# Epoch 86/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9589 - loss: 0.2229 - val_accuracy: 0.9825 - val_loss: 0.1827
# Epoch 87/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9538 - loss: 0.2548 - val_accuracy: 0.9825 - val_loss: 0.1835
# Epoch 88/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9726 - loss: 0.2334 - val_accuracy: 0.9825 - val_loss: 0.1823
# Epoch 89/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9606 - loss: 0.2275 - val_accuracy: 0.9825 - val_loss: 0.1819
# Epoch 90/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9595 - loss: 0.2229 - val_accuracy: 0.9825 - val_loss: 0.1817
# Epoch 91/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9677 - loss: 0.2101 - val_accuracy: 0.9825 - val_loss: 0.1805
# Epoch 92/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9753 - loss: 0.2053 - val_accuracy: 0.9825 - val_loss: 0.1798
# Epoch 93/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9592 - loss: 0.2166 - val_accuracy: 0.9825 - val_loss: 0.1796
# Epoch 94/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9523 - loss: 0.2221 - val_accuracy: 0.9825 - val_loss: 0.1796
# Epoch 95/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9656 - loss: 0.2138 - val_accuracy: 0.9825 - val_loss: 0.1790
# Epoch 96/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9388 - loss: 0.2419 - val_accuracy: 0.9825 - val_loss: 0.1786
# Epoch 97/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9453 - loss: 0.2379 - val_accuracy: 0.9825 - val_loss: 0.1776
# Epoch 98/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9490 - loss: 0.2194 - val_accuracy: 0.9825 - val_loss: 0.1772
# Epoch 99/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9545 - loss: 0.2373 - val_accuracy: 0.9825 - val_loss: 0.1762
# Epoch 100/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9669 - loss: 0.2095 - val_accuracy: 0.9825 - val_loss: 0.1756

# %% [markdown]
# <br><br>
# <div dir="rtl">
# <font size="4">
#     <li>
#         نمودار accuracy و loss مدل را رسم کنید.
# </font>
# </div>

# %%
tr_acc = history.history['accuracy']
tr_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']

epochs = [i+1 for i in range(len(tr_acc))]

plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs, tr_loss, 'r', label='Train Loss')
plt.plot(epochs, val_loss, 'g', label='Valid Loss')
plt.title('Loss')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')

plt.subplot(1, 2, 2)
plt.plot(epochs, tr_acc, 'r', label='Train Accuracy')
plt.plot(epochs, val_acc, 'g', label='Valid Accuracy')
plt.title('Accuracy')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Accuracy')

plt.tight_layout()
plt.show()
